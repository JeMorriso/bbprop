# %%
from nba_api.stats.static import players, teams

# %%
players.find_players_by_full_name('jerami grant')
# Out:
# [{'id': 203924,
#   'full_name': 'Jerami Grant',
#   'first_name': 'Jerami',
#   'last_name': 'Grant',
#   'is_active': True}]

# %%
players.find_players_by_full_name('fwef')
# Out:
# []

# %%
teams.find_teams_by_nickname('cavaliers')
# Out:
# [{'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
from nba_api.stats.endpoints.playergamelogs import PlayerGameLogs
from nba_api.stats.endpoints.playergamelog import PlayerGameLog

# %%
# Does not work properly
jg = PlayerGameLogs(player_id_nullable=203924, last_n_games_nullable=5)

# %%
ljg = jg.get_data_frames()
ljg[0].head()
# Out:
#   SEASON_YEAR  PLAYER_ID   PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0     2016-17     203924  Jerami Grant  1610612760               OKC
# 1     2016-17     203924  Jerami Grant  1610612760               OKC
# 2     2016-17     203924  Jerami Grant  1610612760               OKC
# 3     2016-17     203924  Jerami Grant  1610612760               OKC
#
#                TEAM_NAME     GAME_ID            GAME_DATE      MATCHUP WL  \
# 0  Oklahoma City Thunder  0021601225  2017-04-12T00:00:00  OKC vs. DEN  L
# 1  Oklahoma City Thunder  0021601213  2017-04-11T00:00:00    OKC @ MIN  W
# 2  Oklahoma City Thunder  0021601198  2017-04-09T00:00:00    OKC @ DEN  W
# 3  Oklahoma City Thunder  0021601186  2017-04-07T00:00:00    OKC @ PHX  L
#
#    ...  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  ...         1         4          1        1         2         1
# 1  ...         3         1          4        4         2         2
# ...

# %%
# This one does work, but it's the same as PlayerGameLog
jg = PlayerGameLogs(player_id_nullable=203924, season_nullable='2020-21')

# %%
# Broken
jg = PlayerGameLogs(player_id_nullable=203924, opp_team_id_nullable=1610612739)

# %%
ljg = jg.get_data_frames()
ljg[0].head()
# Out:
#   SEASON_YEAR  PLAYER_ID   PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0     2016-17     203924  Jerami Grant  1610612760               OKC
# 1     2016-17     203924  Jerami Grant  1610612760               OKC
# 2     2016-17     203924  Jerami Grant  1610612760               OKC
# 3     2016-17     203924  Jerami Grant  1610612760               OKC
# 4     2016-17     203924  Jerami Grant  1610612760               OKC
#
#                TEAM_NAME     GAME_ID            GAME_DATE      MATCHUP WL  \
# 0  Oklahoma City Thunder  0021601225  2017-04-12T00:00:00  OKC vs. DEN  L
# 1  Oklahoma City Thunder  0021601213  2017-04-11T00:00:00    OKC @ MIN  W
# 2  Oklahoma City Thunder  0021601198  2017-04-09T00:00:00    OKC @ DEN  W
# 3  Oklahoma City Thunder  0021601186  2017-04-07T00:00:00    OKC @ PHX  L
# 4  Oklahoma City Thunder  0021601159  2017-04-04T00:00:00  OKC vs. MIL  W
#
#    ...  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# ...

# %%
ljg = jg.get_data_frames()
ljg[0].head()
# Out:
#   SEASON_YEAR  PLAYER_ID   PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0     2020-21     203924  Jerami Grant  1610612765               DET
# 1     2020-21     203924  Jerami Grant  1610612765               DET
# 2     2020-21     203924  Jerami Grant  1610612765               DET
# 3     2020-21     203924  Jerami Grant  1610612765               DET
# 4     2020-21     203924  Jerami Grant  1610612765               DET
#
#          TEAM_NAME     GAME_ID            GAME_DATE      MATCHUP WL  ...  \
# 0  Detroit Pistons  0022000257  2021-01-25T00:00:00  DET vs. PHI  W  ...
# 1  Detroit Pistons  0022000243  2021-01-23T00:00:00  DET vs. PHI  L  ...
# 2  Detroit Pistons  0022000230  2021-01-22T00:00:00  DET vs. HOU  L  ...
# 3  Detroit Pistons  0022000219  2021-01-20T00:00:00    DET @ ATL  L  ...
# 4  Detroit Pistons  0022000206  2021-01-18T00:00:00    DET @ MIA  L  ...
#
#    STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# ...

# %%
ljg[0].columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2',
#        'TD3', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
#        'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
#        'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
#        'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
#        'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK',
#        'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK'],
#       dtype='object')

# %%
jg = PlayerGameLog(player_id=203924, season='2020-21')

# %%
l_ = jg.get_data_frames()

# %%
type(l_)
# Out:
# list

# %%
l_[0].head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22020     203924  0022000257  JAN 25, 2021  DET vs. PHI  W   32    6
# 1     22020     203924  0022000243  JAN 23, 2021  DET vs. PHI  L   35    3
# 2     22020     203924  0022000230  JAN 22, 2021  DET vs. HOU  L   35    4
# 3     22020     203924  0022000219  JAN 20, 2021    DET @ ATL  L   41   12
# 4     22020     203924  0022000206  JAN 18, 2021    DET @ MIA  L   34   10
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   13   0.462  ...     5    8    5    1    1    0   4   25          23
# 1   19   0.158  ...     7    9    3    2    1    2   5   11          -8
# 2   15   0.267  ...     7    8    3    0    2    3   1   21          14
# 3   22   0.545  ...     5    6    5    0    0    1   5   32         -10
# 4   19   0.526  ...     3    4    6    0    1    2   4   27          -2
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
# ...

# %%
l_[0].columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2',
#        'TD3', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
#        'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
#        'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
#        'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
#        'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK',
#        'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK'],
#       dtype='object')

# %%
len(l_)
# Out:
# 1

# %%
l_
# Out:
# [   SEASON_YEAR  PLAYER_ID   PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
#  0      2016-17     203924  Jerami Grant  1610612760               OKC
#  1      2016-17     203924  Jerami Grant  1610612760               OKC
#  2      2016-17     203924  Jerami Grant  1610612760               OKC
#  3      2016-17     203924  Jerami Grant  1610612760               OKC
#  4      2016-17     203924  Jerami Grant  1610612760               OKC
#  ..         ...        ...           ...         ...               ...
#  75     2016-17     203924  Jerami Grant  1610612760               OKC
#  76     2016-17     203924  Jerami Grant  1610612760               OKC
#  77     2016-17     203924  Jerami Grant  1610612760               OKC
#  78     2016-17     203924  Jerami Grant  1610612755               PHI
#  79     2016-17     203924  Jerami Grant  1610612755               PHI
#
#                  TEAM_NAME     GAME_ID            GAME_DATE      MATCHUP WL  \
# ...

# %%
from nba_api.stats.endpoints.playerdashboardbylastngames import PlayerDashboardByLastNGames

# %%
jg_dash = PlayerDashboardByLastNGames(203924, last_n_games=5)

# %%
jg_dash

# %%
ljg = jg_dash.get_data_frames()

# %%
ljg[0].head()
# Out:
#   GROUP_SET GROUP_VALUE  GP  W  L  W_PCT         MIN  FGM  FGA  FG_PCT  ...  \
# 0   Overall     2020-21   5  1  4    0.2  176.983333   35   88   0.398  ...
#
#    BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
# 0          1        1         1         1                1
#
#    NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  CFID  CFPARAMS
# 0                     1         1         1    34   2020-21
#
# [1 rows x 62 columns]

# %%
ljg[0].columns
# Out:
# Index(['GROUP_SET', 'GROUP_VALUE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD',
#        'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#        'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#        'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#        'DD2_RANK', 'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')
